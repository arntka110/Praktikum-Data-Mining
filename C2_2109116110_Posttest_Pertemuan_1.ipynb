# %% [markdown]
# <a href="https://colab.research.google.com/github/arntka110/Praktikum-Data-Mining/blob/main/C2_2109116110_Posttest_Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Posttest Praktikum Sistem Informasi </h1>
#
# **NIM : 2109116110**
#
# **NAMA : Ariantika Putri Maharani**
#
# > Kerjakanlah tugas berikut berdasarkan instruksi yang diberkan. Kumpulkanlah hasil posttest ini pada Github dengan mengumpulkan link repository kalian.
#
# Disini ada dua jenis tugas.
#
# 1. Visualisasi
# 2. Penerapan Algoritma Naive Bayes
#
#
# Ketentuan pengumpulan tugas :
# 1. Kumpul Tugas ini dengan Format Kelas_NIM_Posttest 1.ipynb
# 2. Kumpulkan dalam bentuk link repository github
# 3. Berikan penjelasan untuk setiap blok kode dengan membuat text atau comment pada kodingan
# 4. Untuk bagian penjelasan gausa terlalu panjang.
# singkat padat dan jelas

# %% [markdown]
# ## Business Understanding & Data Understanding

# %% [markdown]
# Importlah pandas, seaborn, dan plotly
#
# Download dataset dari link ini [**Link Dataset**](https://github.com/fnikolas-r/Data-Mining-Course/blob/main/Pertemuan%202/ChurnBank.csv)
#
#
#
#
# Kemudian taruhlah dalam sebuah variabel bernama df
#
#
# *note: kalian dapat menambah blok yang ada*

# %%
# Import library
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np

# %% [markdown]
# ## Membuat Dataset

# %%
# Dataset
df = pd.read_csv("ChurnBank.csv")
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# 2         College         Single    $80K - $120K          Blue        3495.0
# 3     High School        Unknown         $120K +          Blue        7793.0
# 4        Graduate         Single  Less than $40K          Blue        2761.0

# %%
df.tail()
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 15        Graduate        Married  Less than $40K          Blue        3111.0
# 16        Graduate        Married  Less than $40K          Blue        7562.0
# 17     High School         Single  Less than $40K          Blue        1438.3
# 18        Graduate         Single     $60K - $80K          Blue        1438.3
# 19   Post-Graduate        Married         Unknown          Blue        2953.0

# %% [markdown]
# ### Business Understanding
#
# Disini kamu berandai andai bahwa kamu adalah direktur sebuah perusahaan, kamu menggunakan dataset ini dan akan menggunakan algoritma Naive Bayes untuk perkembangan perusahaan kamu. Jelaskan tujuan penggunaan dataset ini, tujuan perusahaan, serta tujuan dari penggunaan naive bayes (beri penjelasan di text ini)
#
# **Tujuan Penggunaan Dataset**
#
# Untuk memudahkan perusahaan dalam mengolah data dalam jumlah yang banyak. Selain itu, memudahkan dalam melihat progress perusahaan saya dengan menggunakan visualisasi.
#
# **Tujuan Perusahaan**
#
# Tujuan perusahaan menggunakan dataset adalah untuk menyimpan data perusahaan yang nantinya akan menjadi penentu dalam mengambil suatu keputusan. Selain itu, dataset berguna untuk memantau apa yang akan terjadi pada aktivitas perusahaan saya.
#
# **Tujuan Penggunaan Naive Bayes**
#
# Dari beberapa sumber yang saya baca, tujuan dari penggunaan algoritma naive bayes adalah untuk mengklasifikasikan data berdasarkan probabilitas yang dapat terjadi di masa depan. Selain itu, algoritma naive bayes merupakan algoritma dengan tingkat nilai error yang didapat lebih rendah.

# %% [markdown]
# ## Data Understanding
# Dari dataset diatas buatlah  variabel yang berisi

# %%
# df1 isinya dataset dengan label target AttritedCustomer
df1 = df[df["Attrition_Flag"]=="Attrited Customer"]
df1
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# ...

# %%
# df2 dengan label bukan Attrited customer
df2 = df.Attrition_Flag=="Attrited Customer"
df[~df2]
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# ...

# %%
# df3 dengan tabel untuk usia dibawah 50 tahun
df3 = df[df["Customer_Age"]<50]
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# ...

# %%
# df4 untuk customer yang statusnya itu single
df4 = df[df["Marital_Status"]=="Single"]
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# ...

# %%
# Tampilkan info dataset (df.info()) dan berikan penjelasannya dalam bentuk teks atau comment
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# **Penjelasan dataset (df.info())**
#
# Sebelum melakukan analisis, terlebih dahulu digunakan fungsi “ .info ” untuk menampilkan informasi data yang akan dilakukan analisis.
#
# Data yang akan dianalisis memiliki 10 variabel (kolom) yaitu kolom Unnamed: 0, Attrition_Flag, Customer_Age, Gender, Education_Level, Marital_Status, Income_Category, Card_Category, Credit_Limit yang memiliki type data integer, object, dan float.

# %% [markdown]
# #### Opsional (nilai plus)

# %%
# Tampilkan nilai rata-rata, min,max, dan standar deviasi  untuk setiap kolom bertipe angka
# Kolom Unnamed: 0
df5 = df.agg({"Unnamed: 0": ["mean", "min", "max", "std"]})
df5
# Out:
#         Unnamed: 0
# mean   6105.100000
# min     176.000000
# max   10084.000000
# std    2850.304026

# %%
# Kolom CLIENTNUM
df6 = df.agg({"CLIENTNUM": ["mean", "min", "max", "std"]})
df6
# Out:
#          CLIENTNUM
# mean  7.424893e+08
# min   7.092220e+08
# max   8.098441e+08
# std   4.045524e+07

# %%
# Kolom Customer_Age
df7 = df.agg({"Customer_Age": ["mean", "min", "max", "std"]})
df7
# Out:
#       Customer_Age
# mean     47.250000
# min      32.000000
# max      59.000000
# std       7.859791

# %%
# Kolom Credit_Limit
df8 = df.agg({"Credit_Limit": ["mean", "min", "max", "std"]})
df8
# Out:
#       Credit_Limit
# mean   8114.580000
# min    1438.300000
# max   26792.000000
# std    8331.036819

# %% [markdown]
# #### Explore Data

# %% [markdown]
# ##### Visualisasi Comparison

# %%
# Buatlah visualisasi yang menampilkan berapa banyak yang attrited customer dan tidak
px.histogram(df,x="Attrition_Flag",color="Attrition_Flag",title="Banyak Attrited Customer dan Existing Customer")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan kategori-kategorinya 
# contoh Unknown berapa dsb
px.histogram(df,x="Education_Level",color="Education_Level",title="Banyak Kategori Education Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan gendernya
# contoh M berapa F berapa
px.histogram(df,x="Education_Level",color="Gender",title="Jumlah Gender Education Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Berikan penjelasannya untuk tiap visualsiasi  disini**
#
# Visualisasi comparison ditampilkan dalam bentuk histogram untuk mengetahui jumlah dari setiap atribut data.
#
# 1. Histogram untuk data Banyak Attrited Customer dan Existing Customer menujukkan bahwa pada grafik Attrited Customer berjumlah 10 dan grafik Existing Customer berjumlah 10.
# 2. Histogram untuk data Banyak Kategori Education_Level menujukkan bahwa pada grafik Unknown berjumlah 2, grafik Uneducated berjumlah 5, grafik College berjumlah 1, grafik High School berjumlah 4, grafik Graduate berjumlah 5, grafik Pos-Graduate berjumlah 2, grafik Doctorate berjumlah 1.
# 3. Histogram untuk data Jumlah Gender pada Education_Level menujukkan grafik jumlah gender berdasarkan kategori dari setiap Education Level.

# %% [markdown]
# ##### Visualisasi Distribution

# %%
# Buatlah historgram untuk umur customer dan credit card limit
# Histogram untuk Umur Customer
px.histogram(df,x="Customer_Age",title="Distribusi Umur Customer")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Histogram untuk Credit Limit
px.histogram(df,x="Credit_Limit",title="Distribusi Credit Limit")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Buatlah boxplot untuk umur customer dan credit card limit
# Boxplot untuk Umur Customer
px.box(df,x="Customer_Age",title="Boxplot Umur Customer")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Boxplot untuk Credit_Limit
px.box(df,x="Credit_Limit",title="Boxplot Credit Limit")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Berikan penjelasannya disini**
#
# Visualisasi Distribution ditampilkan dalam bentuk histogram dan boxplot.
# 1. Histogram pada Distribusi Umur Customer menampilkan banyak jumlah tiap frekuensi umur.
# 2. Histogram pada Distribusi Credit Limit menampilkan banyak jumlah tiap frekuensi credit limit.
# 3. Boxplot pada Umur Customer dan Credit Limit menampilkan informasi berupa nilai minimum, quartil 1 dan quartil 3, nilai median (nilai tengah), dan nilai maximal.

# %% [markdown]
# ##### Visualisasi Relationship

# %%
# Buatlah scatterplot untuk umur customer dan credit card limit
px.scatter(df,x="Customer_Age",color="Credit_Limit",title="Scatterplot Umur Customer dan Credit Limit")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### Visualisasi Composition

# %%
# Buatlah pieplot untuk Income Category & Education Level
# pieplot untuk Income Category
px.pie(df,names="Income_Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# pieplot untuk Education Level
px.pie(df,names="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Opsional (Nilai Plus)

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Jenis Kelamin sebagai pemisahnya (color)
sns.boxplot(
    data=df, x="Credit_Limit", y="Gender", hue="Gender",
    medianprops={"color" : "yellow"}
)
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Gender'>

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(
    data=df, x="Credit_Limit", y="Attrition_Flag", hue="Attrition_Flag",
    medianprops={"color" : "yellow"}
)
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Attrition_Flag'>

# %%
# Buatlah visualisasi boxplot Age dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(
    data=df, x="Customer_Age", y="Attrition_Flag", hue="Attrition_Flag",
    medianprops={"color" : "yellow"}
)
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Attrition_Flag'>

# %%
# Buatlah visualisasi countplot  Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)
sns.countplot(data=df,x="Attrition_Flag",hue="Gender")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Buatlah visualisasi heatmap untuk Setiap variabel numerik yang ada
sns.heatmap(df.corr(),cmap="YlGnBu",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Algoritma Naive Bayes dan Preprocessing (pengenalan)

# %%
# sebelum membuat algoritma pertama tama buatlah dataset baru dengan ketentuan
# mengambil dataset df
# Menghapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (initinya yang berupa primary key dan bukan tipe kategori)
# dataset dengan kolom yang sudah dihapus tadi kemudian disimpan di dataframe baru (df baru)

# %%
# ambil dataset
df = pd.read_csv("ChurnBank.csv")
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %%
# Data Frame Baru
data = df.drop(["Unnamed: 0", "CLIENTNUM", "Customer_Age", "Credit_Limit"], axis=1)
dfb = pd.DataFrame(data)
dfb
# Out:
#        Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0   Attrited Customer      M         Unknown         Single     $40K - $60K
# 1   Attrited Customer      M      Uneducated        Married     $60K - $80K
# 2   Attrited Customer      M         College         Single    $80K - $120K
# 3   Attrited Customer      M     High School        Unknown         $120K +
# 4   Attrited Customer      F        Graduate         Single  Less than $40K
# 5   Attrited Customer      M   Post-Graduate        Unknown    $80K - $120K
# 6   Attrited Customer      M     High School         Single     $60K - $80K
# 7   Attrited Customer      F        Graduate         Single  Less than $40K
# 8   Attrited Customer      F      Uneducated        Married         Unknown
# 9   Attrited Customer      M         Unknown         Single    $80K - $120K
# 10  Existing Customer      M       Doctorate         Single     $60K - $80K
# ...

# %%
# Buatlah sebuah fungsi naive bayes dengan ketentuan
# Mengambil data dari dataframe yang telah diproses pada blok sebelumnya (diatas)
# Nama fungsinya adalah naive_bayes
# Mengambil 1 saja parameter yaitu sebuah list berisi kategori

# Outputnya berupa prediksi Attrited Customer atau Existing Customer
# Outputnya berupa tuple (_hasilnya, persentasenya berapa) contoh (Existing Customer, 0.004)

# Tidak boleh menggunakan library manapun selain pandas dan numpy



# contoh
# def naive_bayes(prediksi:list)-> tuple :
#   ........

# jadi nanti saat saya coba masukan data 
# naive_bayes(["F",	"Uneducated","Single", "Unknown	Blue"]) akan keluar tuple berupa ("Attired Customer", 0.002)

# %%
# Pindah data Attrition_Flag ke kolom ujung kanan
cols = dfb.columns.tolist()
cols.remove("Attrition_Flag")
cols.append("Attrition_Flag")
dfb = dfb[cols]

# Hitung jumlah data training dan data testing
N_train = len(dfb)

# Hitung jumlah target
target_counts = dfb.groupby("Attrition_Flag")["Attrition_Flag"].count()

# Hitung prior probability untuk setiap target
prob_prio = target_counts/N_train

# Hitung conditional probability untuk setiap target
prob_kond = {}
for col in dfb.columns[:-1]:
  prob_kond[col] = {}
  for val in dfb[col].unique():
    for target in dfb["Attrition_Flag"].unique():
      count = len(df[(df[col] == val) & (dfb["Attrition_Flag"] == target)])
      prob_kond[col][(val,target)] = count/target_counts[target]

# Fungsi Naive_Bayes
def naive_bayes(a):
  prob_yes = prob_prio["Attrited Customer"]
  prob_no = prob_prio["Existing Customer"]
  for i, col in enumerate(dfb.columns[:-1]):
    prob_yes *= prob_kond[col][(a[i], "Attrited Customer")]
    prob_no *= prob_kond[col][(a[i], "Existing Customer")]

  if prob_yes < prob_no:
    hasil = "Attrited Customer", prob_yes
  else:
    hasil = "Existing Customer", prob_no
  return hasil

# Output hasil
output = naive_bayes(["F", "Uneducated", "Single", "Unknown", "Blue"])
print("Output : ", output)
# Out:
# Output :  ('Attrited Customer', 0.0018)
